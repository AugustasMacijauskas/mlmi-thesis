# %%
# Autoreload
# %load_ext autoreload
# %autoreload 2

# %%
# import os
# os.environ['CUDA_VISIBLE_DEVICES'] = "2"

# %%
from collections import defaultdict

from pathlib import Path

from tqdm.notebook import tqdm

import torch

import datasets
# Don't show progress datasets bars
datasets.disable_progress_bar()
from datasets import load_dataset

import sys
sys.path.insert(0, str(Path.cwd().parent.resolve()))
from model import get_model
from dataset import collator
from utils import get_tokenizer

# %%
device = torch.device(
    f"cuda:2" if torch.cuda.is_available() else "cpu"
)
device
# Out:
# device(type='cuda', index=2)

# %%
tokenizer_name = "meta-llama/Llama-2-7b-hf"

dataset_path = "glue"
dataset_name = "qnli"

# %%
# Tokenizer
tokenizer = get_tokenizer(tokenizer_name)
tokenizer.pad_token = tokenizer.unk_token
tokenizer.model_max_length = 4096
tokenizer
# Out:
# Loading tokenizer meta-llama/Llama-2-7b-hf...
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Using pad_token, but it is not set yet.
# Loaded tokenizer.
# LlamaTokenizerFast(name_or_path='meta-llama/Llama-2-7b-hf', vocab_size=32000, model_max_length=4096, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False), 'unk_token': AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False), 'pad_token': '<unk>'}, clean_up_tokenization_spaces=False)

# %% [markdown]
# ## Dataset

# %%
# Dataset for PPO training
dataset = load_dataset(dataset_path, dataset_name, split="train")
dataset = dataset.shuffle(seed=42).select(range(2048))
print(dataset)
# Out:
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# Loading cached shuffled indices for dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-60510de4495de1ff.arrow
# Dataset({
#     features: ['question', 'sentence', 'label', 'idx'],
#     num_rows: 2048
# })

# %%
def format_label(label):
    return "No" if label else "Yes"

# Dataset template
def get_prompt(example):
    prompt = (
        "### INSTRUCTION: Consider the sentence below in triple backticks "
        "and the corresponding question. Does the sentence contain enough information "
        "to answer the question? Your answer should be either yes or no.\n\n"
        "### DESIRED FORMAT :\n"
        "### ANSWER: <your_answer>\n\n"
        # "Answer: <your_answer>\n"
        # f"Do not print \"{answer_prefix}\" again, just what you think the answer is.\n\n"

        f"### SENTENCE:\n```\n{example['sentence']}\n```\n"
        f"### QUESTION: {example['question']}\n"
        "Remember to output either yes or no.\n"
        f"### ANSWER: "
    )

    # prompt = (
    #     "Consider the sentence below in triple backticks "
    #     "and the corresponding question. Does the sentence contain enough information "
    #     "to answer the question? Your answer should be either yes or no.\n\n"
    #     "Desired format:\n"
    #     "Answer: <your_answer>\n\n"
    #     # "Answer: <your_answer>\n"
    #     # f"Do not print \"{answer_prefix}\" again, just what you think the answer is.\n\n"
    #     f"Sentence:\n```\n{example['sentence']}\n```\n"
    #     f"Question: {example['question']}\n"
    #     f"Answer: "
    # )

    return prompt


input_text = get_prompt(dataset[0])
print(f"'{input_text}'")
# Out:
# '### INSTRUCTION: Consider the sentence below in triple backticks and the corresponding question. Does the sentence contain enough information to answer the question? Your answer should be either yes or no.
#
# ### DESIRED FORMAT :
# ### ANSWER: <your_answer>
#
# ### SENTENCE:
# ```
# Apparently the sailor did not connect with the soldier, as Mahan believed he was innovating the term Middle East.
# ```
# ### QUESTION: Who did not connect with the soldier?
# Remember to output either yes or no.
# ### ANSWER: '

# %% [markdown]
# ## Model

# %%
# Model
# model = get_model(tokenizer_name, device)
model = get_model(tokenizer_name, device, load_in_8bit=True, low_cpu_mem_usage=True)

memory_usage = model.pretrained_model.get_memory_footprint() / (1024 ** 3)
print(f"{memory_usage=:.2f} GB")
# Out:
# Loading policy model...
# Downloading (…)lve/main/config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# is_bf16_possible=False
# kwargs={'load_in_8bit': True, 'low_cpu_mem_usage': True, 'torch_dtype': None}
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Loaded subject model with 6,738,419,713 parameters.
# Model dtype: torch.float16
#
# memory_usage=6.58 GB

# %%
def apply_prompt(batch):
    processed_batch = defaultdict(list)
    for sentence, question in zip(batch["sentence"], batch["question"]):
        example = { "sentence": sentence, "question": question }
        processed_batch["prompt"].append(get_prompt(example))
    
    return processed_batch

def filter_too_long(batch):
    # Substract a bit more to allow for generations to be processed
    return [len(x) < tokenizer.model_max_length - 8 for x in batch["input_ids"]]

processed_dataset = dataset.map(
    lambda batch: apply_prompt(batch), batched=True, num_proc=12
)
processed_dataset = processed_dataset.map(
    lambda batch: tokenizer(batch["prompt"]), batched=True, num_proc=12
)
processed_dataset = processed_dataset.filter(filter_too_long, batched=True, num_proc=12)

# Remove some columns
# processed_dataset = processed_dataset.remove_columns(["token_type_ids"])

processed_dataset.set_format(type="torch", columns=["input_ids", "attention_mask"], output_all_columns=True)
processed_dataset
# Out:
# Dataset({
#     features: ['question', 'sentence', 'label', 'idx', 'prompt', 'input_ids', 'attention_mask'],
#     num_rows: 2048
# })

# %%
print(processed_dataset[0]["prompt"])
# Out:
# ### INSTRUCTION: Consider the sentence below in triple backticks and the corresponding question. Does the sentence contain enough information to answer the question? Your answer should be either yes or no.
#
# ### DESIRED FORMAT :
# ### ANSWER: <your_answer>
#
# ### SENTENCE:
# ```
# Apparently the sailor did not connect with the soldier, as Mahan believed he was innovating the term Middle East.
# ```
# ### QUESTION: Who did not connect with the soldier?
# Remember to output either yes or no.
# ### ANSWER:

# %%
# Push the processed dataset to hub
# processed_dataset.push_to_hub("AugustasM/imdb_vicuna", private=True)

# %%
from trl import PPOTrainer, PPOConfig

config = PPOConfig()

optimizer = None

# We then build the PPOTrainer, passing the model, the reference model, the tokenizer
ppo_trainer = PPOTrainer(
    config,
    model,
    ref_model=None,
    tokenizer=tokenizer,
    dataset=dataset,
    data_collator=collator,
    optimizer=optimizer,
)

# %%
def postprocess_fn(text_batch):
    outputs = []

    for text in text_batch:
        if "Yes" in text:
            outputs.append("Yes")
        elif "No" in text:
            outputs.append("No")
        else:
            outputs.append(text)

    return outputs

# %%
dataloader = torch.utils.data.DataLoader(
    # processed_dataset,
    # processed_dataset.select(range(8)),
    processed_dataset.select(range(128)),
    # processed_dataset.select(range(1024)),
    batch_size=32, collate_fn=collator,
    num_workers=12, shuffle=False,
)
print(f"Dataloader length: {len(dataloader)}")

generation_kwargs = {
    "top_k": 0,
    "top_p": 1.0,
    # "do_sample": False,
    "do_sample": True,
    "pad_token_id": tokenizer.pad_token_id,
    "eos_token_id": 100_000, # why is this value like this?
    "pad_to_multiple_of": 8, # TODO: double-check, but this seems to work and to be faster
    "max_new_tokens": 16,
}

gold_outputs = []
outputs = []
for batch in tqdm(dataloader, total=len(dataloader), leave=False):
    batch_gold_outputs = [format_label(label) for label in batch["label"]]
    gold_outputs.extend(batch_gold_outputs)

    question_tensors = batch["input_ids"]

    response_tensors = ppo_trainer.generate(
        question_tensors,
        return_prompt=False,
        # length_sampler=output_length_sampler, # TODO: can be none
        batch_size=8, # TODO: generations are made in batches
        **generation_kwargs,
    )
    batch["response"] = tokenizer.batch_decode(
        response_tensors, skip_special_tokens=True, spaces_between_special_tokens=False
    )

    # Postprocess
    # batch["response"] = postprocess_fn(batch["response"])

    outputs.extend(batch["response"])

len(outputs), len(gold_outputs)
# Out:
# Dataloader length: 4
#   0%|          | 0/4 [00:00<?, ?it/s]
# (128, 128)

# %%
# for output, golden_output in zip(outputs, gold_outputs):
#     print(f"{golden_output=}\n{output=}")
#     print("-" * 80)

# %%
from collections import Counter

print(len(gold_outputs), len(outputs))
print(Counter(outputs))
# Out:
# 128 128
# Counter({'\n': 29, '\n\n': 2, '\n\n### INSTRUCTION: Consider the sentence below in triple back': 2, '\n\n### SENTENCE:\n```\nAs a result,': 1, '\n### SENTENCE:\n```\nThe length of the Indian': 1, '\n### SOLUTION:\n### SOLUTION:': 1, '1786\n': 1, '\n### NOTE: \n### NOTE: \n##': 1, '\n\n### SENTENCE:\n```\nFor about a de': 1, "\n\n### SENTENCE:\n```\nIBM's": 1, '2004\n### EXPLANATION:\n### This': 1, '\n### EXPLANATION:\nThe sentence only lists the city of': 1, '\n```\nThe Multidimensional Pain Inventory (MPI)': 1, '🚫': 1, '\n\n### SENTENCE:\n```\nThe Best Exotic': 1, '\nYes\n\n### SENTENCE:\n```\nThe ': 1, '\n\n### SENTENCE:\n```\nIn a money saving': 1, '\n\n### SOLUTION:\n\n### ANSW': 1, '\n### SENTENCE:\n```\nThe BOM, code': 1, '\n\n### SUBMIT:\n```\nbash ./submit.sh\n': 1, '\n### SOLUTION:\n```\nThe more remote country pub': 1, '<your_answer>\n': 1, '\n\n### SENTENCE:\n```\nThe line was held': 1, '\n\n### SENTENCE:\n```\n For the 2': 1, '\n### SENTENCE:\n```\nThe particular syntax (sent': 1, '\n\n### SENTENCE:\n```\nStandard Czech is still': 1, '\n### DONE:\n\n': 1, '\n\n\n': 1, 'Yes\n': 1, '\n\n### SENTENCE:\n```\nMarch and April': 1, '0\n\n### SENTENCE:\n```\nThe College Park': 1, '\n\n### SENTENCE:\n```\nThe 19': 1, '\n\n### SENTENCE:\n```\nThe Aryan': 1, '\n\n### SENTENCE:\n```\nThe Oklahoma City metropol': 1, '\n\n### OUTPUT:\n*[Y/N]*\n': 1, '2000\n': 1, '\n\n### SENTENCE:\n```\n\n```\n##': 1, '\n\n### SENTENCE:\n```\nIn the 1': 1, '3\n### SOLUTION:\n```\nDespite this': 1, '❌\n': 1, '\n\n### SENTENCE:\n```\nThe American Civil War': 1, '\nYes\n### SENTENCE:\n```\nThe Court of': 1, '1978\n\n### SENTENCE:\n```\n': 1, '\n\n### SENTENCE:\n```\nBecause of the': 1, '\n\n### SENTENCE:\n```\nThe university was granted': 1, '\n\n### SENTENCE:\n```\nThe Rhone is': 1, '\n### INPUT:\n### OUTPUT:\n### NOT': 1, '32\n\n### SENTENCE:\n```\nHaving': 1, '1989\n\n### SENTENCE:\n```\n': 1, '\n\n### SENTENCE:\n```\nThe tornadoes': 1, '1715\n### ANSWER: 178': 1, '\n### MORE INFORMATION:\n\nhttps://en.wikipedia': 1, '\n```\nyes\n```\n\n### SENTENCE:\n': 1, '\n\n<a id="_4.2.1"></a>\n': 1, '\n\n### SENTENCE:\n```\nThe only thing that': 1, '\nRemember to output either yes or no.\n': 1, '\n\n\n### SENTENCE:\n```\n\n```\n': 1, '\n### QUESTION: Do you think this sentence contains enough information': 1, '\n###### (1) yes\n###### (2) no\n': 1, '1390-1717\n': 1, '\n\n##### HINT:\n- What is the role of green plants': 1, '\n```\nYES\n```\n\n### SENTENCE:\n': 1, '\n### EXPLANATION:\n```\n```\n': 1, '3\n': 1, '\n\n### SENTENCE:\n```\nOn September 2': 1, '\n\n### SENTENCE:\n```\nThe service also en': 1, '\n\n### SENTENCE:\n```\nCongress passed': 1, '1\n': 1, '': 1, '\n\n### SENTENCE:\n\n```\n\n```\n': 1, '140 miles\n\n### SENTENCE:\n```\n': 1, '\n### SENTENCE:\n```\nThere are two kinds of': 1, '352\n\n### CONTINUE TO THE NEXT Q': 1, '1500\n': 1, '\n#### 1. What distinguishes Latin, Greek, and Cyrill': 1, '\n\n### HINT:\n### There are many ways to solve': 1, '\n### SOLUTION:\n### The sentence does not contain': 1, '\n### <a href="https://i.stack.imgur.com': 1, 'The term for someone who has achieved nirvana is arahant.': 1, '\n### SENTENCE:\n```\nTheir primary aircraft complement': 1, '2011\n': 1, '\n\n### SENTENCE:\n```\nOf the total income': 1, '\n\n### ANSWER: Macao Daily News\n\n##': 1, '\n### SOLUTION:\n': 1, '\n\n### SENTENCE:\n```\nThe first Apple Mac': 1, '\nYes\n': 1, '\n```\nno\n```\n': 1, '40 km/h\n': 1, '\nYou can also output the answer in a sentence.\n': 1, '\n### HINT:\n### ALTERNATIVE:\n': 1, '\n### SENTENCE:\n```\nThe US military is known': 1, '\n### ANSWER:\n### ANSWER:': 1, '\n\n### SENTENCE:\n```\nIn 20': 1, '😀\n': 1, '1720\n### EXPLANATION:\n\n###': 1, '\n```\nyes\n```\n### SENTENCE:\n```': 1, '\n### SENTENCE:\n```\nThere are many different audio': 1, '\nWhat causes the meat of some poultry to show rainbow like col': 1})

# %%
print(Counter([x.lower() for x in outputs]))
# Out:
# Counter({'\n\n': 4, '\n```': 2, '17': 1, '9.': 1})

# %%
def get_accuracy(gold_outputs, outputs):
    return sum([1 if gold == output else 0 for gold, output in zip(gold_outputs, outputs)]) / len(outputs)

get_accuracy(gold_outputs, outputs)
# Out:
# 0.490234375

# %%
for output, golden_output in zip(outputs, gold_outputs):
    if output != golden_output:
        print(f"{golden_output=}\n{output=}")
        print("-" * 80)
# Out:
# golden_output='Yes'
# output='Mah'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='The'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='NO'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='S'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Re'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Democratic'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='As'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Do'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='A'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Question'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Ge'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='William'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='It'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='My'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='The'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='H'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='C'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='It'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Anal'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Question'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='h'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Jer'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='The'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Arts'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='NO'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='What'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='I'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Econom'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Question'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Thomas'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Francisco'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='David'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Question'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Wisconsin'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='ph'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Canal'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='In'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='"'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='The'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='The'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Option'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='The'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='True'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='For'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Not'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='EU'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Su'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='The'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Right'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='The'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='"'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='**'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Question'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='"'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output=''
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='no'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Des'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='True'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Two'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='Zak'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Answer'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='<'
# --------------------------------------------------------------------------------
# golden_output='Yes'
# output='No'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
# golden_output='No'
# output='Yes'
# --------------------------------------------------------------------------------
