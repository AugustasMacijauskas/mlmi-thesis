# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
from pathlib import Path

import pandas as pd

# %%
DATA_DIR = Path("../../elk-reporters/gpt2/imdb/jovial-murdock/")
DATA_DIR
# Out:
# PosixPath('../../elk-reporters/gpt2/imdb/jovial-murdock')

# %% [markdown]
# ## Check eval files

# %%
df = pd.read_csv(DATA_DIR / "eval.csv")
df
# Out:
#    dataset  layer ensembling  auroc_estimate  auroc_lower  auroc_upper  \
# 0     imdb      0       full          0.5053       0.4722       0.5384
# 1     imdb      0       none          0.5008       0.4929       0.5084
# 2     imdb      0    partial          0.5014       0.4906       0.5126
# 3     imdb      1       full          0.4660       0.4289       0.5038
# 4     imdb      1       none          0.4764       0.4467       0.5053
# 5     imdb      1    partial          0.4720       0.4391       0.5055
# 6     imdb      2       full          0.5578       0.5220       0.5928
# 7     imdb      2       none          0.5494       0.5187       0.5776
# 8     imdb      2    partial          0.5517       0.5191       0.5834
# 9     imdb      3       full          0.5367       0.5023       0.5713
# 10    imdb      3       none          0.5338       0.5038       0.5629
# 11    imdb      3    partial          0.5346       0.5029       0.5652
# 12    imdb      4       full          0.5993       0.5649       0.6335
# 13    imdb      4       none          0.5821       0.5528       0.6094
# 14    imdb      4    partial          0.5886       0.5577       0.6192
# 15    imdb      5       full          0.5851       0.5499       0.6198
# 16    imdb      5       none          0.5713       0.5419       0.5987
# 17    imdb      5    partial          0.5755       0.5436       0.6064
# 18    imdb      6       full          0.5832       0.5478       0.6175
# 19    imdb      6       none          0.5695       0.5396       0.5970
# 20    imdb      6    partial          0.5776       0.5462       0.6084
# 21    imdb      7       full          0.6301       0.5956       0.6638
# 22    imdb      7       none          0.6067       0.5783       0.6336
# 23    imdb      7    partial          0.6201       0.5887       0.6507
# 24    imdb      8       full          0.6748       0.6419       0.7073
# 25    imdb      8       none          0.6426       0.6151       0.6695
# 26    imdb      8    partial          0.6610       0.6303       0.6910
# 27    imdb      9       full          0.6957       0.6635       0.7285
# 28    imdb      9       none          0.6595       0.6335       0.6850
# 29    imdb      9    partial          0.6793       0.6494       0.7103
# 30    imdb     10       full          0.8446       0.8211       0.8687
# 31    imdb     10       none          0.7648       0.7447       0.7849
# 32    imdb     10    partial          0.8068       0.7845       0.8289
# 33    imdb     11       full          0.8576       0.8344       0.8799
# 34    imdb     11       none          0.7651       0.7460       0.7842
# 35    imdb     11    partial          0.8183       0.7961       0.8396
# 36    imdb     12       full          0.7554       0.7251       0.7826
# 37    imdb     12       none          0.6700       0.6483       0.6890
# 38    imdb     12    partial          0.7250       0.6980       0.7498
#
#     cal_acc_estimate  cal_acc_lower  cal_acc_upper  acc_estimate  acc_lower  \
# 0             0.5030         0.4740         0.5310        0.4960     0.4680
# 1             0.5018         0.4919         0.5115        0.5018     0.4919
# 2             0.5018         0.4919         0.5115        0.5018     0.4919
# 3             0.4760         0.4440         0.5060        0.4680     0.4370
# 4             0.4808         0.4564         0.5056        0.4826     0.4582
# 5             0.4808         0.4564         0.5056        0.4826     0.4582
# 6             0.5400         0.5100         0.5710        0.5380     0.5050
# 7             0.5365         0.5117         0.5612        0.5379     0.5123
# 8             0.5365         0.5117         0.5612        0.5379     0.5123
# 9             0.5340         0.5030         0.5650        0.5350     0.5050
# 10            0.5248         0.5005         0.5482        0.5305     0.5058
# 11            0.5248         0.5005         0.5482        0.5305     0.5058
# 12            0.5820         0.5530         0.6110        0.5790     0.5490
# 13            0.5645         0.5406         0.5882        0.5628     0.5397
# 14            0.5645         0.5406         0.5882        0.5628     0.5397
# 15            0.5700         0.5400         0.6020        0.5660     0.5350
# 16            0.5554         0.5315         0.5795        0.5542     0.5305
# 17            0.5554         0.5315         0.5795        0.5542     0.5305
# 18            0.5580         0.5290         0.5900        0.5590     0.5290
# 19            0.5632         0.5375         0.5882        0.5602     0.5338
# 20            0.5632         0.5375         0.5882        0.5602     0.5338
# 21            0.5920         0.5630         0.6230        0.5940     0.5640
# 22            0.5908         0.5659         0.6150        0.5877     0.5623
# 23            0.5908         0.5659         0.6150        0.5877     0.5623
# 24            0.6180         0.5890         0.6480        0.6210     0.5910
# 25            0.6148         0.5903         0.6388        0.6125     0.5881
# 26            0.6148         0.5903         0.6388        0.6125     0.5881
# 27            0.6440         0.6140         0.6740        0.6380     0.6080
# 28            0.6272         0.6028         0.6518        0.6280     0.6039
# 29            0.6272         0.6028         0.6518        0.6280     0.6039
# 30            0.7560         0.7300         0.7810        0.7550     0.7300
# 31            0.7288         0.7086         0.7479        0.7298     0.7092
# 32            0.7288         0.7086         0.7479        0.7298     0.7092
# 33            0.7740         0.7500         0.8000        0.7660     0.7410
# 34            0.7405         0.7208         0.7603        0.7410     0.7214
# 35            0.7405         0.7208         0.7603        0.7410     0.7214
# 36            0.6720         0.6440         0.7010        0.6770     0.6480
# 37            0.6665         0.6458         0.6887        0.6645     0.6431
# 38            0.6665         0.6458         0.6887        0.6645     0.6431
#
#     acc_upper     ece  pseudo_auroc  train_loss
# 0      0.5240  0.0060           NaN     -0.0000
# 1      0.5115  0.0018           NaN     -0.0000
# 2      0.5115  0.0018           NaN     -0.0000
# 3      0.4990  0.0055           NaN     -0.0022
# 4      0.5069  0.0055           NaN     -0.0022
# 5      0.5069  0.0055           NaN     -0.0022
# 6      0.5680  0.0895           NaN     -0.0040
# 7      0.5612  0.1021           NaN     -0.0040
# 8      0.5612  0.1021           NaN     -0.0040
# 9      0.5650  0.0881           NaN     -0.0106
# 10     0.5528  0.0975           NaN     -0.0106
# 11     0.5528  0.0975           NaN     -0.0106
# 12     0.6090  0.1012           NaN     -0.0174
# 13     0.5853  0.1244           NaN     -0.0174
# 14     0.5853  0.1244           NaN     -0.0174
# 15     0.5960  0.0996           NaN     -0.0214
# 16     0.5790  0.1163           NaN     -0.0214
# 17     0.5790  0.1163           NaN     -0.0214
# 18     0.5900  0.1030           NaN     -0.0278
# 19     0.5842  0.1176           NaN     -0.0278
# 20     0.5842  0.1176           NaN     -0.0278
# 21     0.6240  0.1023           NaN     -0.0367
# 22     0.6126  0.1173           NaN     -0.0367
# 23     0.6126  0.1173           NaN     -0.0367
# 24     0.6510  0.0981           NaN     -0.0520
# 25     0.6371  0.1193           NaN     -0.0520
# 26     0.6371  0.1193           NaN     -0.0520
# 27     0.6670  0.0929           NaN     -0.0636
# 28     0.6529  0.1139           NaN     -0.0636
# 29     0.6529  0.1139           NaN     -0.0636
# 30     0.7820  0.0416           NaN     -0.0713
# 31     0.7491  0.0746           NaN     -0.0713
# 32     0.7491  0.0746           NaN     -0.0713
# 33     0.7920  0.0379           NaN     -0.0737
# 34     0.7600  0.0609           NaN     -0.0737
# 35     0.7600  0.0609           NaN     -0.0737
# 36     0.7050  0.0363           NaN     -0.0002
# 37     0.6857  0.0638           NaN     -0.0002
# 38     0.6857  0.0638           NaN     -0.0002
