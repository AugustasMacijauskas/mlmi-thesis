# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
from pathlib import Path

import pandas as pd

# %%
DATA_DIR = Path("../../../elk-reporters/gpt2/imdb/agitated-clarke/")
# !ls {DATA_DIR}
# Out:
# cfg.yaml  fingerprints.yaml  lr_eval.csv  reporters	  train_lm_eval.csv
# eval.csv  lm_eval.csv	     lr_models	  train_eval.csv

# %% [markdown]
# ## Check eval files

# %%
df = pd.read_csv(DATA_DIR / "eval.csv")
df
# Out:
#    dataset  layer ensembling  auroc_estimate  auroc_lower  auroc_upper  \
# 0     imdb      0       full          0.4975       0.4624       0.5361
# 1     imdb      0       none          0.4971       0.4880       0.5062
# 2     imdb      0    partial          0.4977       0.4854       0.5110
# 3     imdb      1       full          0.4693       0.4329       0.5070
# 4     imdb      1       none          0.4790       0.4494       0.5078
# 5     imdb      1    partial          0.4749       0.4420       0.5083
# 6     imdb      2       full          0.5581       0.5222       0.5931
# 7     imdb      2       none          0.5496       0.5189       0.5778
# 8     imdb      2    partial          0.5520       0.5194       0.5837
# 9     imdb      3       full          0.5367       0.5021       0.5713
# 10    imdb      3       none          0.5338       0.5038       0.5629
# 11    imdb      3    partial          0.5346       0.5029       0.5652
# ...

# %%
df.describe()
# Out:
#           layer  auroc_estimate  auroc_lower  auroc_upper  cal_acc_estimate  \
# count  39.00000       39.000000    39.000000    39.000000         39.000000
# mean    6.00000        0.626041     0.597464     0.654172          0.597815
# std     3.79057        0.110143     0.112604     0.107940          0.085522
# min     0.00000        0.469300     0.432900     0.506200          0.474000
# 25%     3.00000        0.550800     0.519150     0.580750          0.536900
# 50%     6.00000        0.588600     0.557700     0.619200          0.570000
# 75%     9.00000        0.687000     0.656050     0.718100          0.635400
# max    12.00000        0.860900     0.837800     0.883100          0.774000
#
#        cal_acc_lower  cal_acc_upper  acc_estimate  acc_lower  acc_upper  \
# count      39.000000      39.000000     39.000000  39.000000  39.000000
# mean        0.573200       0.622538      0.597395   0.572585   0.621785
# ...

# %%
pd.read_csv(DATA_DIR / "lm_eval.csv").describe()
# Out:
#           layer  auroc_estimate  auroc_lower  auroc_upper  cal_acc_estimate  \
# count  39.00000       39.000000    39.000000    39.000000         39.000000
# mean    6.00000        0.606400     0.592800     0.619367          0.586867
# std     3.79057        0.124129     0.111717     0.135362          0.088923
# min     0.00000        0.505100     0.502800     0.507600          0.524800
# 25%     3.00000        0.505100     0.502800     0.507600          0.524800
# 50%     6.00000        0.535300     0.527500     0.543300          0.524800
# 75%     9.00000        0.778800     0.748100     0.807200          0.711000
# max    12.00000        0.778800     0.748100     0.807200          0.711000
#
#        cal_acc_lower  cal_acc_upper  acc_estimate  acc_lower  acc_upper  \
# count      39.000000      39.000000     39.000000  39.000000  39.000000
# mean        0.571133       0.601667      0.518200   0.502467   0.534667
# ...
