# %%
# !python ../../../lm_evaluation_harness_promptsource/lm-evaluation-harness/main.py \
    --model_api_name 'hf-causal' \
    --model_args pretrained='gpt2-xl' \
    --task_name 'qnli' \
    --device cuda
# Out:
# [codecarbon INFO @ 01:10:51] offline tracker init
#
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 14.79it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 696.07it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 692.36it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 718.86it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 636.01it/s]
#
# » Assigning unique IDs to 'qnli+based only on' docs
#
# » Filtering invalid docs from 'qnli+based only on'
#
# » Constructing 'qnli+based only on' contexts and requests
# 100%|██████████████████████████████████████| 5463/5463 [00:10<00:00, 524.10it/s]
#
# » Assigning unique IDs to 'qnli+have all you need' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-e3791faf14131527.arrow
#
# » Filtering invalid docs from 'qnli+have all you need'
#
# » Constructing 'qnli+have all you need' contexts and requests
# 100%|██████████████████████████████████████| 5463/5463 [00:10<00:00, 534.69it/s]
#
# » Assigning unique IDs to 'qnli+imply' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-e3791faf14131527.arrow
#
# » Filtering invalid docs from 'qnli+imply'
#
# » Constructing 'qnli+imply' contexts and requests
# 100%|██████████████████████████████████████| 5463/5463 [00:10<00:00, 519.06it/s]
#
# » Assigning unique IDs to 'qnli+possible to answer' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-e3791faf14131527.arrow
#
# » Filtering invalid docs from 'qnli+possible to answer'
#
# » Constructing 'qnli+possible to answer' contexts and requests
# 100%|██████████████████████████████████████| 5463/5463 [00:11<00:00, 455.89it/s]
#
# » Assigning unique IDs to 'qnli+want to know' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-e3791faf14131527.arrow
#
# » Filtering invalid docs from 'qnli+want to know'
#
# » Constructing 'qnli+want to know' contexts and requests
# 100%|██████████████████████████████████████| 5463/5463 [00:10<00:00, 522.38it/s]
#
# » Running all `loglikelihood` requests
#   7%|██▊                                   | 3990/54630 [06:21<41:03, 20.55it/s]^C
#   7%|██▋                                 | 3994/54630 [06:21<1:20:36, 10.47it/s]
# Traceback (most recent call last):
#   File "../../../lm_evaluation_harness_promptsource/lm-evaluation-harness/main.py", line 215, in <module>
#     main()
#   File "../../../lm_evaluation_harness_promptsource/lm-evaluation-harness/main.py", line 197, in main
#     results = evaluator.cli_evaluate(**evaluate_args)
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/evaluator.py", line 90, in cli_evaluate
#     results = evaluate(
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/evaluator.py", line 220, in evaluate
#     resps = getattr(model, reqtype)([req.args for req in reqs])
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/api/model.py", line 179, in loglikelihood
#     return self._loglikelihood_tokens(new_requests)
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/api/model.py", line 310, in _loglikelihood_tokens
#     self._model_call(batched_inputs), dim=-1
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/models/huggingface.py", line 388, in _model_call
#     return self.model(inputs)["logits"]
#   File "/fsx/home-augustas/anaconda3/envs/eval-harness/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/fsx/home-augustas/anaconda3/envs/eval-harness/lib/python3.8/site-packages/transformers/models/gpt2/modeling_gpt2.py", line 1076, in forward
#     transformer_outputs = self.transformer(
#   File "/fsx/home-augustas/anaconda3/envs/eval-harness/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/fsx/home-augustas/anaconda3/envs/eval-harness/lib/python3.8/site-packages/transformers/models/gpt2/modeling_gpt2.py", line 900, in forward
#     outputs = block(
#   File "/fsx/home-augustas/anaconda3/envs/eval-harness/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/fsx/home-augustas/anaconda3/envs/eval-harness/lib/python3.8/site-packages/transformers/models/gpt2/modeling_gpt2.py", line 428, in forward
#     feed_forward_hidden_states = self.mlp(hidden_states)
#   File "/fsx/home-augustas/anaconda3/envs/eval-harness/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/fsx/home-augustas/anaconda3/envs/eval-harness/lib/python3.8/site-packages/transformers/models/gpt2/modeling_gpt2.py", line 357, in forward
#     hidden_states = self.c_proj(hidden_states)
#   File "/fsx/home-augustas/anaconda3/envs/eval-harness/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/fsx/home-augustas/anaconda3/envs/eval-harness/lib/python3.8/site-packages/transformers/pytorch_utils.py", line 105, in forward
#     x = torch.addmm(self.bias, x.view(-1, x.size(-1)), self.weight)
# KeyboardInterrupt
