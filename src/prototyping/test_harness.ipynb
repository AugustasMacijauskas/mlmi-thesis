# %%
# !python ../../../lm_evaluation_harness_promptsource/lm-evaluation-harness/main.py \
    --model_api_name 'hf-causal' \
    --model_args pretrained='gpt2-xl' \
    --task_name 'rte' \
    --device cuda
# Out:
# [codecarbon INFO @ 23:48:35] offline tracker init
#
# Downloading and preparing dataset glue/rte to /admin/home-augustas/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# Downloading data: 100%|██████████████████████| 697k/697k [00:00<00:00, 18.2MB/s]
# Dataset glue downloaded and prepared to /admin/home-augustas/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 335.94it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|███████████████████████████████████████████| 3/3 [00:00<00:00, 1003.66it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|███████████████████████████████████████████| 3/3 [00:00<00:00, 1115.01it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|███████████████████████████████████████████| 3/3 [00:00<00:00, 1043.79it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 970.83it/s]
#
# » Assigning unique IDs to 'rte+does the claim… follow the fact…' docs
#
# » Filtering invalid docs from 'rte+does the claim… follow the fact…'
#
# » Constructing 'rte+does the claim… follow the fact…' contexts and requests
# 100%|████████████████████████████████████████| 277/277 [00:00<00:00, 461.22it/s]
#
# » Assigning unique IDs to 'rte+entailment explained' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-11693129d0370e31.arrow
#
# » Filtering invalid docs from 'rte+entailment explained'
#
# » Constructing 'rte+entailment explained' contexts and requests
# 100%|████████████████████████████████████████| 277/277 [00:00<00:00, 437.27it/s]
#
# » Assigning unique IDs to 'rte+imply' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-11693129d0370e31.arrow
#
# » Filtering invalid docs from 'rte+imply'
#
# » Constructing 'rte+imply' contexts and requests
# 100%|████████████████████████████████████████| 277/277 [00:00<00:00, 466.51it/s]
#
# » Assigning unique IDs to 'rte+imply separated' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-11693129d0370e31.arrow
#
# » Filtering invalid docs from 'rte+imply separated'
#
# » Constructing 'rte+imply separated' contexts and requests
# 100%|████████████████████████████████████████| 277/277 [00:00<00:00, 502.75it/s]
#
# » Assigning unique IDs to 'rte+mean' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-11693129d0370e31.arrow
#
# » Filtering invalid docs from 'rte+mean'
#
# » Constructing 'rte+mean' contexts and requests
# 100%|████████████████████████████████████████| 277/277 [00:00<00:00, 506.11it/s]
#
# » Running all `loglikelihood` requests
# 100%|███████████████████████████████████████| 2770/2770 [03:21<00:00, 13.72it/s]
# Traceback (most recent call last):
#   File "../../../lm_evaluation_harness_promptsource/lm-evaluation-harness/main.py", line 215, in <module>
#     main()
#   File "../../../lm_evaluation_harness_promptsource/lm-evaluation-harness/main.py", line 197, in main
#     results = evaluator.cli_evaluate(**evaluate_args)
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/evaluator.py", line 90, in cli_evaluate
#     results = evaluate(
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/evaluator.py", line 242, in evaluate
#     output = task.process_results(doc, per_doc_results)
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/api/task.py", line 511, in process_results
#     assert isinstance(target, list) and len(target) == 1
# AssertionError

# %%
# !python ../../../lm_evaluation_harness_promptsource/lm-evaluation-harness/main.py \
    --model_api_name 'hf-causal' \
    --model_args pretrained='gpt2-xl' \
    --task_name 'qnli' \
    --device cuda
# Out:
# [codecarbon INFO @ 23:52:45] offline tracker init
#
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 12.60it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 674.65it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 705.76it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 688.91it/s]
# Found cached dataset glue (/admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 822.90it/s]
#
# » Assigning unique IDs to 'qnli+based only on' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-e3791faf14131527.arrow
#
# » Filtering invalid docs from 'qnli+based only on'
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-13e77e090165cafb.arrow
# Loading cached shuffled indices for dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-dbae7c43741e7632.arrow
#
# » Constructing 'qnli+based only on' contexts and requests
# 100%|██████████████████████████████████████| 5463/5463 [00:10<00:00, 521.56it/s]
#
# » Assigning unique IDs to 'qnli+have all you need' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-e3791faf14131527.arrow
#
# » Filtering invalid docs from 'qnli+have all you need'
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-a1ca8488110d154d.arrow
# Loading cached shuffled indices for dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-387ac030eb72e8f3.arrow
#
# » Constructing 'qnli+have all you need' contexts and requests
# 100%|██████████████████████████████████████| 5463/5463 [00:10<00:00, 543.21it/s]
#
# » Assigning unique IDs to 'qnli+imply' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-e3791faf14131527.arrow
#
# » Filtering invalid docs from 'qnli+imply'
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-9e60bb6410bce339.arrow
#
# » Constructing 'qnli+imply' contexts and requests
# 100%|██████████████████████████████████████| 5463/5463 [00:10<00:00, 528.55it/s]
#
# » Assigning unique IDs to 'qnli+possible to answer' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-e3791faf14131527.arrow
#
# » Filtering invalid docs from 'qnli+possible to answer'
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-eba5de4c20b4a751.arrow
#
# » Constructing 'qnli+possible to answer' contexts and requests
# 100%|██████████████████████████████████████| 5463/5463 [00:12<00:00, 453.57it/s]
#
# » Assigning unique IDs to 'qnli+want to know' docs
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-e3791faf14131527.arrow
#
# » Filtering invalid docs from 'qnli+want to know'
# Loading cached processed dataset at /admin/home-augustas/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-7f5260e265afbfb4.arrow
#
# » Constructing 'qnli+want to know' contexts and requests
# 100%|██████████████████████████████████████| 5463/5463 [00:10<00:00, 525.71it/s]
#
# » Running all `loglikelihood` requests
# 100%|█████████████████████████████████████| 54630/54630 [48:30<00:00, 18.77it/s]
# Traceback (most recent call last):
#   File "../../../lm_evaluation_harness_promptsource/lm-evaluation-harness/main.py", line 215, in <module>
#     main()
#   File "../../../lm_evaluation_harness_promptsource/lm-evaluation-harness/main.py", line 197, in main
#     results = evaluator.cli_evaluate(**evaluate_args)
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/evaluator.py", line 90, in cli_evaluate
#     results = evaluate(
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/evaluator.py", line 242, in evaluate
#     output = task.process_results(doc, per_doc_results)
#   File "/fsx/home-augustas/lm_evaluation_harness_promptsource/lm-evaluation-harness/lm_eval/api/task.py", line 511, in process_results
#     if answer_choices_list:
# AssertionError
